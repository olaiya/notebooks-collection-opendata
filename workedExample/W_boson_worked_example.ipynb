# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.18/04

# %% [markdown]
# ## Retrieve data

# %% [markdown]
# ### Data

# %%
#1 lepton data
data = [ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/Data/data_A.1lep.root"),
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/Data/data_B.1lep.root"),
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/Data/data_C.1lep.root"),
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/Data/data_D.1lep.root"), 
]

data_trees = [f.Get("mini") for f in data]

# %% [markdown]
# ### Monte-Carlo

# %%
#Single top
single_top = [ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_410011.single_top_tchan.1lep.root"),
              ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_410012.single_antitop_tchan.1lep.root"),
              ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_410013.single_top_wtchan.1lep.root"),
              ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_410014.single_antitop_wtchan.1lep.root"),
              ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_410025.single_top_schan.1lep.root"),
              ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_410026.single_antitop_schan.1lep.root"),
]

single_top_trees = [f.Get("mini") for f in single_top]

# %%
#T-tbar
ttbar = [ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_363356.ZqqZll.1lep.root"),
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_363358.WqqZll.1lep.root"),
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_363359.WpqqWmlv.1lep.root"),
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_363360.WplvWmqq.1lep.root"),
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_363489.WlvZqq.1lep.root"),
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_363490.llll.1lep.root"),
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_363491.lllv.1lep.root"),
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_363492.llvv.1lep.root"),
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_363493.lvvv.1lep.root"),
]

ttbar_trees = [f.Get("mini") for f in ttbar]

# %%
#Z+jets
Zjets = [ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364100.Zmumu_PTV0_70_CVetoBVeto.1lep.root       "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364101.Zmumu_PTV0_70_CFilterBVeto.1lep.root     "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364102.Zmumu_PTV0_70_BFilter.1lep.root          "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364103.Zmumu_PTV70_140_CVetoBVeto.1lep.root     "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364104.Zmumu_PTV70_140_CFilterBVeto.1lep.root   "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364105.Zmumu_PTV70_140_BFilter.1lep.root        "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364106.Zmumu_PTV140_280_CVetoBVeto.1lep.root    "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364107.Zmumu_PTV140_280_CFilterBVeto.1lep.root  "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364108.Zmumu_PTV140_280_BFilter.1lep.root       "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364109.Zmumu_PTV280_500_CVetoBVeto.1lep.root    "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364110.Zmumu_PTV280_500_CFilterBVeto.1lep.root  "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364111.Zmumu_PTV280_500_BFilter.1lep.root       "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364112.Zmumu_PTV500_1000.1lep.root              "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364113.Zmumu_PTV1000_E_CMS.1lep.root            "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364114.Zee_PTV0_70_CVetoBVeto.1lep.root         "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364115.Zee_PTV0_70_CFilterBVeto.1lep.root       "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364116.Zee_PTV0_70_BFilter.1lep.root            "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364117.Zee_PTV70_140_CVetoBVeto.1lep.root       "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364118.Zee_PTV70_140_CFilterBVeto.1lep.root     "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364119.Zee_PTV70_140_BFilter.1lep.root          "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364120.Zee_PTV140_280_CVetoBVeto.1lep.root      "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364121.Zee_PTV140_280_CFilterBVeto.1lep.root    "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364122.Zee_PTV140_280_BFilter.1lep.root         "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364123.Zee_PTV280_500_CVetoBVeto.1lep.root      "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364124.Zee_PTV280_500_CFilterBVeto.1lep.root    "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364125.Zee_PTV280_500_BFilter.1lep.root         "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364126.Zee_PTV500_1000.1lep.root                "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364127.Zee_PTV1000_E_CMS.1lep.root              "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364128.Ztautau_PTV0_70_CVetoBVeto.1lep.root     "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364129.Ztautau_PTV0_70_CFilterBVeto.1lep.root   "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364130.Ztautau_PTV0_70_BFilter.1lep.root        "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364131.Ztautau_PTV70_140_CVetoBVeto.1lep.root   "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364132.Ztautau_PTV70_140_CFilterBVeto.1lep.root "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364133.Ztautau_PTV70_140_BFilter.1lep.root      "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364134.Ztautau_PTV140_280_CVetoBVeto.1lep.root  "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364135.Ztautau_PTV140_280_CFilterBVeto.1lep.root"),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364136.Ztautau_PTV140_280_BFilter.1lep.root     "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364137.Ztautau_PTV280_500_CVetoBVeto.1lep.root  "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364138.Ztautau_PTV280_500_CFilterBVeto.1lep.root"),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364139.Ztautau_PTV280_500_BFilter.1lep.root     "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364140.Ztautau_PTV500_1000.1lep.root            "),  
         ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364141.Ztautau_PTV1000_E_CMS.1lep.root          "),    
]

Zjets_trees = [f.Get("mini") for f in Zjets]

# %%
#W+jets
Wjets =[ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364156.Wmunu_PTV0_70_CVetoBVeto.1lep.root     "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364157.Wmunu_PTV0_70_CFilterBVeto.1lep.root   "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364158.Wmunu_PTV0_70_BFilter.1lep.root        "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364159.Wmunu_PTV70_140_CVetoBVeto.1lep.root   "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364160.Wmunu_PTV70_140_CFilterBVeto.1lep.root "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364161.Wmunu_PTV70_140_BFilter.1lep.root      "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364162.Wmunu_PTV140_280_CVetoBVeto.1lep.root  "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364163.Wmunu_PTV140_280_CFilterBVeto.1lep.root"),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364164.Wmunu_PTV140_280_BFilter.1lep.root     "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364165.Wmunu_PTV280_500_CVetoBVeto.1lep.root  "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364166.Wmunu_PTV280_500_CFilterBVeto.1lep.root"),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364167.Wmunu_PTV280_500_BFilter.1lep.root     "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364168.Wmunu_PTV500_1000.1lep.root            "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364169.Wmunu_PTV1000_E_CMS.1lep.root          "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364170.Wenu_PTV0_70_CVetoBVeto.1lep.root      "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364171.Wenu_PTV0_70_CFilterBVeto.1lep.root    "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364172.Wenu_PTV0_70_BFilter.1lep.root         "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364173.Wenu_PTV70_140_CVetoBVeto.1lep.root    "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364174.Wenu_PTV70_140_CFilterBVeto.1lep.root  "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364175.Wenu_PTV70_140_BFilter.1lep.root       "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364176.Wenu_PTV140_280_CVetoBVeto.1lep.root   "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364177.Wenu_PTV140_280_CFilterBVeto.1lep.root "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364178.Wenu_PTV140_280_BFilter.1lep.root      "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364179.Wenu_PTV280_500_CVetoBVeto.1lep.root   "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364180.Wenu_PTV280_500_CFilterBVeto.1lep.root "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364181.Wenu_PTV280_500_BFilter.1lep.root      "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364182.Wenu_PTV500_1000.1lep.root             "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364183.Wenu_PTV1000_E_CMS.1lep.root           "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364184.Wtaunu_PTV0_70_CVetoBVeto.1lep.root    "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364185.Wtaunu_PTV0_70_CFilterBVeto.1lep.root  "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364186.Wtaunu_PTV0_70_BFilter.1lep.root       "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364187.Wtaunu_PTV70_140_CVetoBVeto.1lep.root  "),
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364188.Wtaunu_PTV70_140_CFilterBVeto.1lep.root"),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364189.Wtaunu_PTV70_140_BFilter.1lep.root     "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364190.Wtaunu_PTV140_280_CVetoBVeto.1lep.root "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364191.Wtaunu_PTV140_280_CFilterBVeto.1lep.root"),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364192.Wtaunu_PTV140_280_BFilter.1lep.root    "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364193.Wtaunu_PTV280_500_CVetoBVeto.1lep.root "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364194.Wtaunu_PTV280_500_CFilterBVeto.1lep.root"),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364195.Wtaunu_PTV280_500_BFilter.1lep.root    "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364196.Wtaunu_PTV500_1000.1lep.root           "),  
        ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_364197.Wtaunu_PTV1000_E_CMS.1lep.root         "), 
]

Wjets_trees = [f.Get("mini") for f in Wjets]

# %%
#Diboson
Diboson = [ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_363356.ZqqZll.1lep.root  "),  
           ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_363358.WqqZll.1lep.root  "),  
           ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_363359.WpqqWmlv.1lep.root"),  
           ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_363360.WplvWmqq.1lep.root"),  
           ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_363489.WlvZqq.1lep.root  "),  
           ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_363490.llll.1lep.root    "),  
           ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_363491.lllv.1lep.root    "),  
           ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_363492.llvv.1lep.root    "),  
           ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_363493.lvvv.1lep.root    "),       
]

Diboson_trees = [f.Get("mini") for f in Diboson]

# %%
Data = [data_trees]
Sim  = [single_top_trees,ttbar_trees,Diboson_trees,Zjets_trees,Wjets_trees]

# %% [markdown]
# ## Set up canvas and histogram

# %%
canvas = ROOT.TCanvas("Canvas","MET_canvas",800,600)

# %%
h_dat     = ROOT.TH1F("h_dat","MET; Missing energy E_{T}^{miss} [GeV] ; events",26,20,200)

#Want to plot all the simulated samples seperately
h_t       = ROOT.TH1F("h_t","MET; Missing energy E_{T}^{miss} [GeV] ; events",26,20,200)
h_ttbar   = ROOT.TH1F("h_ttbar","MET; Missing energy E_{T}^{miss} [GeV] ; events",26,20,200)
h_diboson = ROOT.TH1F("h_diboson","MET; Missing energy E_{T}^{miss} [GeV] ; events",26,20,200)
h_Zjets   = ROOT.TH1F("h_Zjets","MET; Missing energy E_{T}^{miss} [GeV] ; events",26,20,200)
h_Wjets   = ROOT.TH1F("h_Wjets","MET; Missing energy E_{T}^{miss} [GeV] ; events",26,20,200)

data_hists = [h_dat]
sim_hists  = [h_t,h_ttbar,h_diboson,h_Zjets,h_Wjets]

# %% [markdown]
# ## Set up any functions we will need
#
# Useful for repeated operations

# %%
def trackProgress(n,m):
    """
    Function which prints the event loop progress every m events 
    
    Parameters
    ----------
    n : Number of events processed so far
    
    m : Printout event interval
    
    """
    if n == 0:
        print("Event loop tracker")
        print("------------------")
    
    if(n%m==0):
        print("%d events processed" % n)

# %%
def mcWeights(tree,lumi=10):
    """
    When MC simulation is compared to data the contribution of each simulated event needs to be
    scaled ('reweighted') to account for differences in how some objects behave in simulation
    vs in data, as well as the fact that there are different numbers of events in the MC tree than 
    in the data tree.
    
    Parameters
    ----------
    tree : TTree entry for this event
    """
    
    #These values don't change from event to event
    norm = lumi*(tree.XSection*1000)/tree.SumWeights
    
    #These values do change from event to event
    scale_factors = tree.scaleFactor_ELE*tree.scaleFactor_MUON*tree.scaleFactor_LepTRIGGER*tree.scaleFactor_PILEUP*tree.mcWeight
    
    weight = norm*scale_factors
    return weight

# %%
def goodLeptons(tree):
    """
    A function to return the indices of 'good leptons' (electrons or muons) in an event. This follows 
    many of the same steps as locateGoodPhotons() and photonIsolation() in Co-Creation3_HiggsSearch.
    
    Parameters
    ----------
    tree : TTree entry for this event
    """
    
    #Initialise (set up) the variables we want to return
    goodlepton_index = [] #Indices (position in list of event's leptons) of our good leptons
            
    ##Loop through all the leptons in the event
    for j in range(0,tree.lep_n):
            
        ##Check lepton pT
        if tree.lep_pt[j] > 35000:
            
            #Store lepton's index
            goodlepton_index.append(j)

    return goodlepton_index #return list of good lepton indices

# %%
def W_production(tree,hist,mode):
    """
    Function which executes the analysis flow for the W production measurement.
    
    Fills a histogram with MET of events which pass the full set of cuts 
    
    Parameters
    ----------
    tree : A Ttree containing data / background information
    
    hist : The name of the histogram to be filled with mT(llvv) values
    
    mode : A flag to tell the function if it is looping over 'data' or 'mc'
    """
    
    n = 0
    for event in tree:
        
        #############################
        ### Event-level requirements
        #############################
    
        trackProgress(n,100000)
        n += 1
        
        #If event is MC: Reweight it
        if mode.lower() == 'mc': weight = mcWeights(tree)
        else: weight = 1
            
            
        #If the event passes either the electron or muon trigger
        if tree.trigE or tree.trigM:
            
            ####Lepton preselections
            goodLeps = goodLeptons(tree) #If the datafiles were not already filtered by number of leptons

            ###################################
            ### Individual lepton requirements
            ###################################

            if len(goodLeps) == 1: #Exactly one good lepton...

                #####################
                ### MET requirements
                #####################

                #Initialse (set up) an empty 4 vector for the event's MET and fill from tree
                met_four_mom = ROOT.TLorentzVector()
                met_four_mom.SetPtEtaPhiE(tree.met_et,0,tree.met_phi,tree.met_et)

                #MET > 30 GeV
                if met_four_mom.Pt() > 30000:

                    ##################
                    ### W requirements
                    ##################
                    
                    # Because of conservation of energy/momentum, the W boson 4-momentum
                    # = (lepton 4-momentum + MET (i.e. neutrino) 4-momentum)

                    #Initialse (set up) an empty 4 vector for dilepton system
                    W_four_mmtm = ROOT.TLorentzVector()

                    #Initialse (set up) an empty 4 vector for the lepton
                    lep_four_mmtm = ROOT.TLorentzVector()
                    lep_four_mmtm.SetPtEtaPhiE(tree.lep_pt[0], tree.lep_eta[0],tree.lep_phi[0],tree.lep_E[0])

                    #Store lepton's 4 momentum
                    W_four_mmtm = lep_four_mmtm + met_four_mom
                    
                    #W 'Transverse mass' > 60 GeV
                    if W_four_mmtm.Mt() > 60000:
                                                
                        #If Fill() is passed a second argument, the event is weighted by that amount
                        hist.Fill(tree.met_et/1000,weight)

# %% [markdown]
# ## Execute event loop

# %% [markdown]
# ### Data

# %%
#Data
for i in range(0,len(Data)):
    hist      = data_hists[i]
    tree_list = Data[i]
    for tree in tree_list:
        print("\nNumber of events in file: %d\n" % tree.GetEntries())
        W_production(tree,hist,'data')
# Out:
# Number of events in file: 9796409
#
# Event loop tracker
# ------------------
# 0 events processed
# 100000 events processed
# 200000 events processed
# 300000 events processed
# 400000 events processed
# 500000 events processed
# 600000 events processed
# 700000 events processed
# 800000 events processed
# 900000 events processed
# 1000000 events processed
# 1100000 events processed
# 1200000 events processed
# 1300000 events processed
# 1400000 events processed
# 1500000 events processed
# 1600000 events processed
# 1700000 events processed
# 1800000 events processed
# 1900000 events processed
# 2000000 events processed
# 2100000 events processed
# 2200000 events processed
# 2300000 events processed
# 2400000 events processed
# 2500000 events processed
# 2600000 events processed
# 2700000 events processed
# 2800000 events processed
# 2900000 events processed
# 3000000 events processed
# 3100000 events processed
# 3200000 events processed
# 3300000 events processed
# ...

# %%
h_dat.SetMarkerStyle(20) #Choose the shape for our markers
h_dat.SetMarkerSize(0.5) #Choose the size for our markers
h_dat.Draw("P") #Plot bin markers
canvas.SetLogy() #Set y axis to log scale
canvas.Draw()

# %%
#MC
for i in range(0,len(Sim)):
    print("\n### Sample number: %d ###" % i)
    hist      = sim_hists[i]
    tree_list = Sim[i]
    for tree in tree_list:
        print("\nNumber of events in file: %d\n" % tree.GetEntries())
        W_production(tree,hist,'mc')
# Out:
# ### Sample number: 0 ###
#
# Number of events in file: 1480867
#
# Event loop tracker
# ------------------
# 0 events processed
# 100000 events processed
# 200000 events processed
# 300000 events processed
# 400000 events processed
# 500000 events processed
# 600000 events processed
# 700000 events processed
# 800000 events processed
# 900000 events processed
# 1000000 events processed
# 1100000 events processed
# 1200000 events processed
# 1300000 events processed
# 1400000 events processed
#
# Number of events in file: 1551985
#
# Event loop tracker
# ------------------
# 0 events processed
# 100000 events processed
# 200000 events processed
# 300000 events processed
# 400000 events processed
# 500000 events processed
# 600000 events processed
# 700000 events processed
# 800000 events processed
# 900000 events processed
# 1000000 events processed
# 1100000 events processed
# 1200000 events processed
# 1300000 events processed
# 1400000 events processed
# 1500000 events processed
#
# ...

# %% [markdown]
# ## Plotting

# %%
#Some formatting options

h_dat.SetMarkerStyle(20) #Choose the shape for our markers
h_dat.SetMarkerSize(0.5) #Choose the size for our markers

h_t.SetFillColor(7)
h_ttbar.SetFillColor(5)
h_diboson.SetFillColor(9)
h_Zjets.SetFillColor(6)
h_Wjets.SetFillColor(3)

h_t.SetLineColor(1)
h_ttbar.SetLineColor(1)
h_diboson.SetLineColor(1)
h_Zjets.SetLineColor(1)
h_Wjets.SetLineColor(1)

# %% [markdown]
# ### Creating a stacked histogram

# %%
#How to create a stacked histogram
hs1 = ROOT.THStack("hs1"," stacked")

hs1.Add(h_t)
hs1.Add(h_ttbar)
hs1.Add(h_diboson)
hs1.Add(h_Zjets)
hs1.Add(h_Wjets)

# %% [markdown]
# ### Add a legend

# %%
h_dat.SetStats(0) #Remove the stats box

legend=ROOT.TLegend(0.75,0.7,0.9,0.9) #Add a legend instead
legend.AddEntry(h_dat,"Data","p")
legend.AddEntry(h_Wjets,"W+jets","f")
legend.AddEntry(h_Zjets,"Z+jets","f")
legend.AddEntry(h_diboson,"Diboson","f")
legend.AddEntry(h_ttbar,"ttbar","f")
legend.AddEntry(h_t,"Single top","f")
# Out:
# <ROOT.TLegendEntry object ("TLegendEntry") at 0x55eb9b6048b0>

# %% [markdown]
# ### Get drawing!!!

# %%
h_dat.Draw("P") #Plot bin markers
hs1.Draw("histsame")
legend.Draw()

canvas.SetLogy() #Set y axis to log scale
canvas.Draw()

# %% [markdown]
# # All done!!!
